# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../weather_database_/WeatherPy_Database.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID      City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Qostanay      KZ  53.1667   63.5833     17.89        79
# 1        1  Saldanha      ZA -33.0117   17.9442     68.05        68
# 2        2  Xuanzhou      CN  30.9525  118.7553     50.32        72
# 3        3    Atuona      PF  -9.8000 -139.0333     79.12        79
# 4        4    Avarua      CK -21.2078 -159.7750     80.65        83
#
#    Cloudiness  Wind Speed Current Description
# 0          40       15.66    scattered clouds
# 1           0        5.17           clear sky
# 2         100        6.85     overcast clouds
# 3           6       19.91           clear sky
# 4          75        2.30       broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
preferred_cities_df.head(10)

# Display sample data
# Out:
#     City_ID               City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3             Atuona      PF  -9.8000 -139.0333     79.12        79
# 4         4             Avarua      CK -21.2078 -159.7750     80.65        83
# 6         6  Sao Joao Da Barra      BR -21.6403  -41.0511     74.91        90
# 7         7             Rawson      AR -43.3002  -65.1023     71.87        51
# 8         8       Port Lincoln      AU -34.7333  135.8667     71.96        63
# 10       10           Takoradi      GH   4.8845   -1.7554     77.86        90
# 11       11          Alappuzha      IN   9.4900   76.3264     81.61        70
# 13       13            Bourail      NC -21.5667  165.4833     80.04        81
# 15       15           Kingston      JM  17.9970  -76.7936     76.15        73
# 18       18              Ponot      PH   8.4520  123.0222     82.56        75
#
#     Cloudiness  Wind Speed Current Description
# 3            6       19.91           clear sky
# 4           75        2.30       broken clouds
# 6           95       12.21     overcast clouds
# 7           17       11.63          few clouds
# 8            3       19.91           clear sky
# 10          16        5.79          few clouds
# 11          54        3.89       broken clouds
# 13         100       10.25          light rain
# 15          20        6.91          few clouds
# 18          77       15.21       broken clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.head()
# Out:
#    City_ID               City Country      Lat       Lng  Max Temp  Humidity  \
# 3        3             Atuona      PF  -9.8000 -139.0333     79.12        79
# 4        4             Avarua      CK -21.2078 -159.7750     80.65        83
# 6        6  Sao Joao Da Barra      BR -21.6403  -41.0511     74.91        90
# 7        7             Rawson      AR -43.3002  -65.1023     71.87        51
# 8        8       Port Lincoln      AU -34.7333  135.8667     71.96        63
#
#    Cloudiness  Wind Speed Current Description
# 3           6       19.91           clear sky
# 4          75        2.30       broken clouds
# 6          95       12.21     overcast clouds
# 7          17       11.63          few clouds
# 8           3       19.91           clear sky

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[['City', 'Country', 'Max Temp', 'Current Description', 'Lat', 'Lng']].copy()
hotel_df.head()
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng
# 3             Atuona      PF     79.12           clear sky  -9.8000 -139.0333
# 4             Avarua      CK     80.65       broken clouds -21.2078 -159.7750
# 6  Sao Joao Da Barra      BR     74.91     overcast clouds -21.6403  -41.0511
# 7             Rawson      AR     71.87          few clouds -43.3002  -65.1023
# 8       Port Lincoln      AU     71.96           clear sky -34.7333  135.8667

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df['Hotel_Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 3             Atuona      PF     79.12           clear sky  -9.8000 -139.0333
# 4             Avarua      CK     80.65       broken clouds -21.2078 -159.7750
# 6  Sao Joao Da Barra      BR     74.91     overcast clouds -21.6403  -41.0511
# 7             Rawson      AR     71.87          few clouds -43.3002  -65.1023
# 8       Port Lincoln      AU     71.96           clear sky -34.7333  135.8667
#
#   Hotel_Name
# 3
# 4
# 6
# 7
# 8

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Atuona - nearest hotel: Pearl Resort
# Avarua - nearest hotel: Paradise Inn
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Rawson - nearest hotel: Hotel Deportivo
# Port Lincoln - nearest hotel: Boston Hotel
# Takoradi - nearest hotel: Hillcrest
# Alappuzha - nearest hotel: Unnis Hotel
# Bourail - nearest hotel: Hôtel Restaurant La Néra
# Kingston - nearest hotel: Aphrodite Hotel
# Ponot - nearest hotel: No hotel found
# Cape Town - nearest hotel: Townhouse Hotel
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Naifaru - nearest hotel: No hotel found
# Saint-Georges - nearest hotel: Deyna's City Inn
# Charters Towers - nearest hotel: No hotel found
# Lashio - nearest hotel: Golden Kaniri Hotel
# Nhulunbuy - nearest hotel: No hotel found
# Hobart - nearest hotel: Vibe Hotel Hobart
# Champerico - nearest hotel: Hotel y Restaurante El Submarino
# Hilo - nearest hotel: Dolphin Bay Hotel
# Kapaa - nearest hotel: Pono Kai Resort
# San Juan - nearest hotel: Hotel San Francisco
# Kota Belud - nearest hotel: U Hotel
# Ormara - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: Pebbles Inn
# Souillac - nearest hotel: Hotel SkylineInn
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Nibong Tebal - nearest hotel: Golden Ace Hotel
# Cidreira - nearest hotel: Hotel Castelo
# Kavaratti - nearest hotel: No hotel found
# Bengkulu - nearest hotel: Dena Hotel
# Salalah - nearest hotel: Muscat International Hotel
# Tual - nearest hotel: Suita
# San Rafael - nearest hotel: Hotel Regional
# Bathsheba - nearest hotel: Atlantis Hotel
# Omboue - nearest hotel: Georges Faustin Aurat
# Geraldton - nearest hotel: Ocean Centre Hotel
# Saint-Philippe - nearest hotel: Le Baril
# Bredasdorp - nearest hotel: Victoria Hotel
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Kavieng - nearest hotel: Kavieng Hotel
# Busselton - nearest hotel: No hotel found
# Moerai - nearest hotel: Manotel Rurutu
# Clarence Town - nearest hotel: Erringhi Hotel
# Mersing - nearest hotel: Mersing Inn Hotel
# Karimganj - nearest hotel: No hotel found
# Butaritari - nearest hotel: No hotel found
# Vaini - nearest hotel: Keleti International Resort
# Santo Antonio Do Ica - nearest hotel: No hotel found
# Yazman - nearest hotel: Yazman Banquet Marriage Hall
# Hobyo - nearest hotel: No hotel found
# Axim - nearest hotel: Axim Beach Hotel
# Hermanus - nearest hotel: Aloe guest house
# Neiafu - nearest hotel: Port Wine Guest House
# Mogadishu - nearest hotel: SYL Hotel
# Georgetown - nearest hotel: Page 63 hostel
# Carnarvon - nearest hotel: No hotel found
# Basak - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Presidencia Roque Saenz Pena - nearest hotel: Hotel Presidente
# Maragogi - nearest hotel: Pousada Mariluz
# Tampakan - nearest hotel: No hotel found
# Conakry - nearest hotel: Hotel del Fanta (sleazy but rooms for 100k or even less)
# Payakumbuh - nearest hotel: Hotel Mangkuto
# Galle - nearest hotel: Jungle Hostel Villa
# Quelimane - nearest hotel: Mabassa
# Lima - nearest hotel: Hotel Peach Garden
# Kibala - nearest hotel: No hotel found
# Manoel Urbano - nearest hotel: No hotel found
# Pisco - nearest hotel: La Portada
# Bairiki - nearest hotel: Marry's Motel
# San Matias - nearest hotel: Hotel San Jose
# Grand Gaube - nearest hotel: Coco Villa
# Ternate - nearest hotel: Boulivard ternate
# Arraial Do Cabo - nearest hotel: No hotel found
# Marsh Harbour - nearest hotel: Lofty Fig Villas
# Dingle - nearest hotel: No hotel found
# Tungi - nearest hotel: Hotel Holiday Inn হোটেল হলিডে ইন
# Faanui - nearest hotel: Oa Oa Lodge
# Eyl - nearest hotel: فندق ايل دابي
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Magadi - nearest hotel: Udupi Upahara
# Lodja - nearest hotel: No hotel found
# Mahebourg - nearest hotel: Grand Bel Air
# Vila Velha - nearest hotel: Hotel Prainha
# Oranjestad - nearest hotel: Hotel California
# Olinda - nearest hotel: Fidji Motel
# Ha Tinh - nearest hotel: Hong Chau Nha Nhgi
# Ballina - nearest hotel: Ballina Beach Resort
# Bangkalan - nearest hotel: Ningrat traditional hotel
# Yanam - nearest hotel: No hotel found
# Kruisfontein - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Burnie - nearest hotel: Burnie Central TownHouse Hotel
# Antsohihy - nearest hotel: Escale
# Dzilam Gonzalez - nearest hotel: No hotel found
# Yenagoa - nearest hotel: Peretimi Hotels Ltd.
# Papetoai - nearest hotel: Ancien Intercontinental (fermé)
# Padang - nearest hotel: losmen Surya
# Luanda - nearest hotel: Hotel Forum
# Talara - nearest hotel: Hospedaje El Aypate
# Kendari - nearest hotel: City Hotel Kendari
# High Rock - nearest hotel: No hotel found
# Bowen - nearest hotel: Whitsunday Sands Resort
# Candolim - nearest hotel: bluesea Beach Resort
# Puerto Quijarro - nearest hotel: No hotel found
# Banda Aceh - nearest hotel: Hotel 61
# Kupang - nearest hotel: BIB & LANG GUEST HOUSE
# Namatanai - nearest hotel: Namatanai Hotel
# Fenoarivo - nearest hotel: Les Herons
# Kiunga - nearest hotel: No hotel found
# Bonthe - nearest hotel: No hotel found
# Bagua Grande - nearest hotel: Hotel Adria'n
# Esperance - nearest hotel: Hospitality
# Cartagena - nearest hotel: Hotel Bellamar
# Haapiti - nearest hotel: No hotel found
# Soyo - nearest hotel: Hotel Maria Teres
# Beloha - nearest hotel: No hotel found
# Tamandare - nearest hotel: Pousada Baia dos Corais
# Quang Ngai - nearest hotel: Ngoc Anh
# Sawtell - nearest hotel: Boambee Bay Resort
# Mahibadhoo - nearest hotel: Coral View Inn
# Auki - nearest hotel: No hotel found
# Port Macquarie - nearest hotel: The Observatory
# Mount Gambier - nearest hotel: The Old Mount Gambier Gaol
# Bandar - nearest hotel: No hotel found
# Podor - nearest hotel: La Cour du Fleuve
# Hualmay - nearest hotel: Hotel Mi Choacan
# Springbok - nearest hotel: Elkoweru Guesthouse
# Tiarei - nearest hotel: No hotel found
# Labuhan - nearest hotel: No hotel found
# Minab - nearest hotel: هتل صدف
# Alofi - nearest hotel: No hotel found
# Azoyu - nearest hotel: No hotel found
# San Vicente De Canete - nearest hotel: Hotel Colibrí
# Hirara - nearest hotel: 古謝そば屋
# Huarmey - nearest hotel: Hostal Santa Rosa
# Esperantinopolis - nearest hotel: No hotel found
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Santa Cruz - nearest hotel: Aviador Hotel Boutique
# Fare - nearest hotel: hôtel Maitai Lapita Village
# Jacareacanga - nearest hotel: Hotel São Cristovão
# Flinders - nearest hotel: No hotel found
# Xuddur - nearest hotel: No hotel found
# Lookan - nearest hotel: No hotel found
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Acarau - nearest hotel: No hotel found
# Inhambane - nearest hotel: Hotel de Inhambane
# Tabou - nearest hotel: hôtel le rochet
# Barmer - nearest hotel: No hotel found
# Kloulklubed - nearest hotel: The Adventures Inn
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Isangel - nearest hotel: Tanna Lodge
# Sur - nearest hotel: Sur Hotel
# General Pico - nearest hotel: Euskadi Hotel
# Koupela - nearest hotel: White Stone Hôtel
# Yarada - nearest hotel: No hotel found
# Gizo - nearest hotel: Gizo Hotel
# Sabang - nearest hotel: Sabang Hill
# Sarangani - nearest hotel: No hotel found
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Wanning - nearest hotel: No hotel found
# Touros - nearest hotel: Pousada Atlântico
# Nuevitas - nearest hotel: Hotel Caonaba
# Kulhudhuffushi - nearest hotel: No hotel found
# Mossendjo - nearest hotel: Louesse Palace
# Basco - nearest hotel: Tawsen Hotel
# Bulungu - nearest hotel: No hotel found
# Bambous Virieux - nearest hotel: No hotel found
# Witu - nearest hotel: No hotel found
# Bambanglipuro - nearest hotel: No hotel found
# Lukang - nearest hotel: 永樂酒店
# Cayenne - nearest hotel: Central Hôtel
# Dubti - nearest hotel: No hotel found
# Tura - nearest hotel: No hotel found
# Lahaina - nearest hotel: Best Western Pioneer Inn
# Merauke - nearest hotel: No hotel found
# Timbiqui - nearest hotel: Hotel de Río Timbiqui
# Ibra - nearest hotel: الدكيك
# Ulladulla - nearest hotel: Hotel Marlin
# Lamu - nearest hotel: Hotel Archipelago villa bed and breakfast
# Santa Catalina - nearest hotel: No hotel found
# Boyolangu - nearest hotel: No hotel found
# Rong Kwang - nearest hotel: Hotel
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Kita - nearest hotel: Hotel Chats Rouges
# Port-Gentil - nearest hotel: Tara-Mé
# Les Cayes - nearest hotel: No hotel found
# Jampur - nearest hotel: City Marriage Hall
# Kudahuvadhoo - nearest hotel: No hotel found
# Butembo - nearest hotel: Canada House
# Falam - nearest hotel: No hotel found
# Meulaboh - nearest hotel: Hotel Meuligou
# Sola - nearest hotel: No hotel found
# Bandundu - nearest hotel: Majestik Hotel
# Lao Cai - nearest hotel: Bảo Son Hotel
# Kapit - nearest hotel: Haip
# Nuqui - nearest hotel: Puerta del Sol
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Sibolga - nearest hotel: Hotel Prima Indah
# Tecoanapa - nearest hotel: No hotel found
# Ugoofaaru - nearest hotel: No hotel found
# Micheweni - nearest hotel: No hotel found
# Andilamena - nearest hotel: Hotely Magic
# Tsabong - nearest hotel: No hotel found
# Vanimo - nearest hotel: CBC Guesthouse
# Kerouane - nearest hotel: No hotel found
# Palu - nearest hotel: Ujung Pandang Hotel
# Muisne - nearest hotel: Hostal Té de Menta
# Oistins - nearest hotel: The Abidah By Accra
# Puerto Leguizamo - nearest hotel: Hotel Girasoles
# Juba - nearest hotel: Hotel Juba Regency
# Palasa - nearest hotel: No hotel found
# Wawa - nearest hotel: No hotel found
# Bhuj - nearest hotel: Hotel Prince
# Bougouni - nearest hotel: Hotel Piemont
# Ouango - nearest hotel: No hotel found
# Luwuk - nearest hotel: No hotel found
# Moron - nearest hotel: La Esquina
# Plettenberg Bay - nearest hotel: Milkwood Manor
# Tucuman - nearest hotel: Suites San Luis
# Tuy Hoa - nearest hotel: Vinh Tuan Hotel
# Codrington - nearest hotel: No hotel found
# Isla Mujeres - nearest hotel: Villa La Bella
# Itarantim - nearest hotel: No hotel found
# Marsabit - nearest hotel: Chicho Hotel
# Itarema - nearest hotel: Pousada Oásis
# Keti Bandar - nearest hotel: No hotel found
# Kieta - nearest hotel: No hotel found
# Buala - nearest hotel: No hotel found
# Tutoia - nearest hotel: Pousada San Vicente
# Madimba - nearest hotel: No hotel found
# Tagusao - nearest hotel: Shaman's Breath- Beach, Bed & Breakfast
# Bongandanga - nearest hotel: No hotel found
# Douala - nearest hotel: Hotel Man
# Acari - nearest hotel: No hotel found
# Koungou - nearest hotel: Hôtel Trévani
# Key Largo - nearest hotel: Key Largo Inn
# Owo - nearest hotel: No hotel found
# Nicoya - nearest hotel: Hotel marianela
# Jagtial - nearest hotel: No hotel found
# Mae Sai - nearest hotel: ปิยะพรฮิลล์ พาราไดซ์
# Barahona - nearest hotel: Hotel Baramar
# Sambava - nearest hotel: Royal Sava Hôtel
# Bantilan - nearest hotel: Coste Resort
# Caravelas - nearest hotel: Pousada dos Navegantes
# Marawi - nearest hotel: Marawi Resort Hotel
# Marco - nearest hotel: Snook Inn
# Paita - nearest hotel: Victor's
#                   City Country  Max Temp Current Description      Lat  \
# 3               Atuona      PF     79.12           clear sky  -9.8000
# 4               Avarua      CK     80.65       broken clouds -21.2078
# 6    Sao Joao Da Barra      BR     74.91     overcast clouds -21.6403
# 7               Rawson      AR     71.87          few clouds -43.3002
# 8         Port Lincoln      AU     71.96           clear sky -34.7333
# ..                 ...     ...       ...                 ...      ...
# 674           Bantilan      PH     80.91    scattered clouds  14.7519
# 676          Caravelas      BR     72.70       broken clouds -17.7125
# 679             Marawi      PH     76.98    scattered clouds   7.9986
# 684              Marco      US     71.62           clear sky  25.9726
# 685              Paita      PE     75.38     overcast clouds  -5.0892
#
#           Lng Hotel_Name              Hotel Name
# 3   -139.0333                       Pearl Resort
# 4   -159.7750                       Paradise Inn
# 6    -41.0511               Pousada Mediterrâneo
# 7    -65.1023                    Hotel Deportivo
# 8    135.8667                       Boston Hotel
# ..        ...        ...                     ...
# 674  121.6656                       Coste Resort
# 676  -39.2481             Pousada dos Navegantes
# 679  124.2928                Marawi Resort Hotel
# 684  -81.7290                          Snook Inn
# 685  -81.1144                           Victor's
#
# [249 rows x 8 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df['Hotel Name'] != "No hotel found"]
clean_hotel_df = clean_hotel_df.drop('Hotel_Name', axis='columns')
clean_hotel_df.head()
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 3             Atuona      PF     79.12           clear sky  -9.8000 -139.0333
# 4             Avarua      CK     80.65       broken clouds -21.2078 -159.7750
# 6  Sao Joao Da Barra      BR     74.91     overcast clouds -21.6403  -41.0511
# 7             Rawson      AR     71.87          few clouds -43.3002  -65.1023
# 8       Port Lincoln      AU     71.96           clear sky -34.7333  135.8667
#
#              Hotel Name
# 3          Pearl Resort
# 4          Paradise Inn
# 6  Pousada Mediterrâneo
# 7       Hotel Deportivo
# 8          Boston Hotel

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_file, index_label="city_id")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)
