# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]     
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qostanay
# Processing Record 2 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | xuanzhou
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | sao joao da barra
# Processing Record 9 of Set 1 | rawson
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | takoradi
# Processing Record 13 of Set 1 | alappuzha
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | bourail
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 1 | kingston
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | san lawrenz
# Processing Record 21 of Set 1 | ponot
# Processing Record 22 of Set 1 | emmett
# Processing Record 23 of Set 1 | ahipara
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | betlitsa
# Processing Record 28 of Set 1 | bemidji
# Processing Record 29 of Set 1 | naifaru
# Processing Record 30 of Set 1 | goderich
# Processing Record 31 of Set 1 | saint-georges
# Processing Record 32 of Set 1 | novopavlovsk
# Processing Record 33 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | virginia beach
# Processing Record 36 of Set 1 | charters towers
# Processing Record 37 of Set 1 | kortkeros
# Processing Record 38 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 1 | lashio
# Processing Record 40 of Set 1 | nhulunbuy
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | udachnyy
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | olenino
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | saint george
# Processing Record 48 of Set 1 | champerico
# Processing Record 49 of Set 1 | egvekinot
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | garden city
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | san juan
# Processing Record 11 of Set 2 | kota belud
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | mafra
# Processing Record 14 of Set 2 | klaksvik
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | ormara
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | vardo
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | agirish
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | beringovskiy
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | nibong tebal
# Processing Record 27 of Set 2 | sangin
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | nome
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | sal rei
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 2 | salalah
# Processing Record 37 of Set 2 | kahama
# Processing Record 38 of Set 2 | tual
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | san rafael
# Processing Record 41 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | omboue
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | rorvik
# Processing Record 49 of Set 2 | sangmelima
# Processing Record 50 of Set 2 | goure
# Processing Record 1 of Set 3 | valparaiso
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | darnah
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | busselton
# Processing Record 9 of Set 3 | moerai
# Processing Record 10 of Set 3 | cherskiy
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | sydney
# Processing Record 13 of Set 3 | whitehorse
# Processing Record 14 of Set 3 | palmer
# Processing Record 15 of Set 3 | clarence town
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 18 of Set 3 | east wenatchee bench
# Processing Record 19 of Set 3 | mersing
# Processing Record 20 of Set 3 | karimganj
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | mingaora
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | santo antonio do ica
# Processing Record 27 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 3 | la fleche
# Processing Record 29 of Set 3 | zyryanka
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | hasaki
# Processing Record 32 of Set 3 | la maddalena
# Processing Record 33 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | nouadhibou
# Processing Record 36 of Set 3 | asau
# Processing Record 37 of Set 3 | hami
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | awjilah
# Processing Record 40 of Set 3 | yazman
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | hobyo
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | axim
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | tilichiki
# Processing Record 48 of Set 3 | san vicente
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | zhanakorgan
# Processing Record 1 of Set 4 | floro
# Processing Record 2 of Set 4 | laguna
# Processing Record 3 of Set 4 | yairipok
# Processing Record 4 of Set 4 | abadan
# Processing Record 5 of Set 4 | neiafu
# Processing Record 6 of Set 4 | mogadishu
# Processing Record 7 of Set 4 | georgetown
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | general cepeda
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | basak
# Processing Record 12 of Set 4 | tuatapere
# Processing Record 13 of Set 4 | tankhoy
# Processing Record 14 of Set 4 | kenai
# Processing Record 15 of Set 4 | skopelos
# Processing Record 16 of Set 4 | kupino
# Processing Record 17 of Set 4 | fenyi
# Processing Record 18 of Set 4 | vao
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | krutinka
# Processing Record 21 of Set 4 | broome
# Processing Record 22 of Set 4 | castro
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | east wenatchee
# Processing Record 25 of Set 4 | presidencia roque saenz pena
# Processing Record 26 of Set 4 | dikson
# Processing Record 27 of Set 4 | caluquembe
# Processing Record 28 of Set 4 | la sarre
# Processing Record 29 of Set 4 | bethel
# Processing Record 30 of Set 4 | maragogi
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | tampakan
# Processing Record 33 of Set 4 | balad
# Processing Record 34 of Set 4 | comodoro rivadavia
# Processing Record 35 of Set 4 | tibiri
# Processing Record 36 of Set 4 | conakry
# Processing Record 37 of Set 4 | sobolevo
# Processing Record 38 of Set 4 | dagda
# Processing Record 39 of Set 4 | ayagoz
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | bara
# Processing Record 42 of Set 4 | falkoping
# City not found. Skipping...
# Processing Record 43 of Set 4 | qasigiannguit
# Processing Record 44 of Set 4 | senneterre
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | ilulissat
# Processing Record 47 of Set 4 | hemsedal
# Processing Record 48 of Set 4 | payakumbuh
# Processing Record 49 of Set 4 | logrono
# Processing Record 50 of Set 4 | galle
# Processing Record 1 of Set 5 | quelimane
# Processing Record 2 of Set 5 | mehamn
# Processing Record 3 of Set 5 | lima
# Processing Record 4 of Set 5 | sharan
# Processing Record 5 of Set 5 | zhangjiakou
# Processing Record 6 of Set 5 | mayo
# Processing Record 7 of Set 5 | torbay
# Processing Record 8 of Set 5 | kibala
# Processing Record 9 of Set 5 | fort nelson
# Processing Record 10 of Set 5 | manoel urbano
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | bairiki
# Processing Record 13 of Set 5 | nurota
# Processing Record 14 of Set 5 | yar-sale
# Processing Record 15 of Set 5 | san matias
# Processing Record 16 of Set 5 | vila
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | atar
# Processing Record 19 of Set 5 | vanavara
# Processing Record 20 of Set 5 | zhezkazgan
# Processing Record 21 of Set 5 | grand gaube
# Processing Record 22 of Set 5 | george
# Processing Record 23 of Set 5 | ternate
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | siniscola
# Processing Record 27 of Set 5 | riyadh
# Processing Record 28 of Set 5 | ayr
# Processing Record 29 of Set 5 | sheltozero
# Processing Record 30 of Set 5 | arraial do cabo
# Processing Record 31 of Set 5 | marzuq
# Processing Record 32 of Set 5 | batagay
# Processing Record 33 of Set 5 | marsh harbour
# Processing Record 34 of Set 5 | dongsheng
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | foam lake
# Processing Record 37 of Set 5 | buraydah
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | tungi
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | tungor
# Processing Record 42 of Set 5 | eyl
# Processing Record 43 of Set 5 | mnogovershinnyy
# Processing Record 44 of Set 5 | clyde river
# Processing Record 45 of Set 5 | tashla
# Processing Record 46 of Set 5 | manitouwadge
# Processing Record 47 of Set 5 | port blair
# Processing Record 48 of Set 5 | magadi
# Processing Record 49 of Set 5 | lodja
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | matagami
# Processing Record 2 of Set 6 | alice springs
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | peniche
# Processing Record 5 of Set 6 | vila velha
# Processing Record 6 of Set 6 | oranjestad
# Processing Record 7 of Set 6 | olinda
# Processing Record 8 of Set 6 | college
# Processing Record 9 of Set 6 | erzin
# Processing Record 10 of Set 6 | leningradskiy
# Processing Record 11 of Set 6 | ha tinh
# Processing Record 12 of Set 6 | westport
# Processing Record 13 of Set 6 | ballina
# Processing Record 14 of Set 6 | severo-kurilsk
# Processing Record 15 of Set 6 | teguldet
# Processing Record 16 of Set 6 | okhotsk
# Processing Record 17 of Set 6 | tambovka
# Processing Record 18 of Set 6 | bangkalan
# Processing Record 19 of Set 6 | alcanede
# Processing Record 20 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 6 | yanam
# Processing Record 22 of Set 6 | new london
# Processing Record 23 of Set 6 | kruisfontein
# Processing Record 24 of Set 6 | boa vista
# Processing Record 25 of Set 6 | pula
# Processing Record 26 of Set 6 | ankara
# Processing Record 27 of Set 6 | burnie
# Processing Record 28 of Set 6 | fukue
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | antsohihy
# Processing Record 31 of Set 6 | dzilam gonzalez
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | karatau
# Processing Record 34 of Set 6 | pryozerne
# Processing Record 35 of Set 6 | yenagoa
# Processing Record 36 of Set 6 | aswan
# Processing Record 37 of Set 6 | namtsy
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | papetoai
# Processing Record 42 of Set 6 | padang
# Processing Record 43 of Set 6 | sibiti
# Processing Record 44 of Set 6 | luanda
# Processing Record 45 of Set 6 | havre-saint-pierre
# Processing Record 46 of Set 6 | talara
# Processing Record 47 of Set 6 | kendari
# Processing Record 48 of Set 6 | itoman
# Processing Record 49 of Set 6 | alekseyevka
# Processing Record 50 of Set 6 | high rock
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | yuzhno-kurilsk
# Processing Record 3 of Set 7 | kearney
# Processing Record 4 of Set 7 | elliot lake
# Processing Record 5 of Set 7 | bowen
# Processing Record 6 of Set 7 | lasa
# Processing Record 7 of Set 7 | candolim
# Processing Record 8 of Set 7 | tessalit
# Processing Record 9 of Set 7 | kolosovka
# Processing Record 10 of Set 7 | kununurra
# Processing Record 11 of Set 7 | puerto quijarro
# Processing Record 12 of Set 7 | lukovetskiy
# Processing Record 13 of Set 7 | wladyslawowo
# Processing Record 14 of Set 7 | moose factory
# Processing Record 15 of Set 7 | banda aceh
# Processing Record 16 of Set 7 | bonavista
# Processing Record 17 of Set 7 | kaitangata
# Processing Record 18 of Set 7 | kupang
# Processing Record 19 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 7 | namatanai
# Processing Record 21 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 22 of Set 7 | fenoarivo
# Processing Record 23 of Set 7 | adrar
# Processing Record 24 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 7 | nouakchott
# Processing Record 28 of Set 7 | yulara
# Processing Record 29 of Set 7 | kiunga
# Processing Record 30 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | bonthe
# Processing Record 33 of Set 7 | doha
# Processing Record 34 of Set 7 | bagua grande
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | hofn
# Processing Record 37 of Set 7 | minsk
# Processing Record 38 of Set 7 | rybnaya sloboda
# Processing Record 39 of Set 7 | chandler
# Processing Record 40 of Set 7 | manalurpet
# City not found. Skipping...
# Processing Record 41 of Set 7 | kuchinarai
# Processing Record 42 of Set 7 | saint-augustin
# Processing Record 43 of Set 7 | north myrtle beach
# Processing Record 44 of Set 7 | chuy
# Processing Record 45 of Set 7 | vilyuysk
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 7 | ulaangom
# Processing Record 49 of Set 7 | haines junction
# Processing Record 50 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 8 | cartagena
# Processing Record 2 of Set 8 | haapiti
# Processing Record 3 of Set 8 | soyo
# Processing Record 4 of Set 8 | wakkanai
# Processing Record 5 of Set 8 | beloha
# Processing Record 6 of Set 8 | tamandare
# Processing Record 7 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 8 of Set 8 | esmeraldas
# Processing Record 9 of Set 8 | quang ngai
# Processing Record 10 of Set 8 | terme
# Processing Record 11 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 8 | sawtell
# Processing Record 13 of Set 8 | kargasok
# Processing Record 14 of Set 8 | merke
# Processing Record 15 of Set 8 | mahibadhoo
# Processing Record 16 of Set 8 | auki
# Processing Record 17 of Set 8 | port macquarie
# Processing Record 18 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 8 | manbij
# Processing Record 20 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 8 | brooks
# Processing Record 22 of Set 8 | gornyak
# Processing Record 23 of Set 8 | waspan
# Processing Record 24 of Set 8 | abu dhabi
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | frederico westphalen
# Processing Record 27 of Set 8 | bandar
# Processing Record 28 of Set 8 | podor
# Processing Record 29 of Set 8 | talavera de la reina
# Processing Record 30 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | lumphat
# Processing Record 33 of Set 8 | mugur-aksy
# Processing Record 34 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 8 | deputatskiy
# Processing Record 36 of Set 8 | hualmay
# Processing Record 37 of Set 8 | springbok
# Processing Record 38 of Set 8 | saint anthony
# Processing Record 39 of Set 8 | tomatlan
# Processing Record 40 of Set 8 | russell
# Processing Record 41 of Set 8 | ubinskoye
# Processing Record 42 of Set 8 | coahuayana
# Processing Record 43 of Set 8 | tiarei
# Processing Record 44 of Set 8 | portland
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | labuhan
# Processing Record 47 of Set 8 | shache
# Processing Record 48 of Set 8 | emporia
# Processing Record 49 of Set 8 | minab
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | la ronge
# Processing Record 2 of Set 9 | azoyu
# Processing Record 3 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 9 | asyut
# Processing Record 5 of Set 9 | san vicente de canete
# Processing Record 6 of Set 9 | smoky lake
# Processing Record 7 of Set 9 | imbituba
# Processing Record 8 of Set 9 | skegness
# Processing Record 9 of Set 9 | urengoy
# Processing Record 10 of Set 9 | baoqing
# Processing Record 11 of Set 9 | hirara
# Processing Record 12 of Set 9 | pangnirtung
# Processing Record 13 of Set 9 | kashi
# Processing Record 14 of Set 9 | changji
# Processing Record 15 of Set 9 | nyurba
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | kungurtug
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | huarmey
# Processing Record 20 of Set 9 | emerald
# Processing Record 21 of Set 9 | esperantinopolis
# Processing Record 22 of Set 9 | puerto escondido
# Processing Record 23 of Set 9 | roma
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | patitirion
# Processing Record 26 of Set 9 | santa cruz
# Processing Record 27 of Set 9 | kamiiso
# Processing Record 28 of Set 9 | ojinaga
# Processing Record 29 of Set 9 | fare
# Processing Record 30 of Set 9 | piney green
# Processing Record 31 of Set 9 | cesky brod
# Processing Record 32 of Set 9 | reichenau
# Processing Record 33 of Set 9 | barcelos
# Processing Record 34 of Set 9 | ivanovka
# Processing Record 35 of Set 9 | jacareacanga
# Processing Record 36 of Set 9 | flinders
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | chokurdakh
# Processing Record 39 of Set 9 | xuddur
# Processing Record 40 of Set 9 | lookan
# Processing Record 41 of Set 9 | ponta delgada
# Processing Record 42 of Set 9 | nichinan
# Processing Record 43 of Set 9 | isla vista
# Processing Record 44 of Set 9 | lensk
# Processing Record 45 of Set 9 | malinovoye ozero
# Processing Record 46 of Set 9 | mecca
# Processing Record 47 of Set 9 | orcopampa
# Processing Record 48 of Set 9 | alta floresta
# Processing Record 49 of Set 9 | acarau
# Processing Record 50 of Set 9 | lake havasu city
# Processing Record 1 of Set 10 | ayan
# Processing Record 2 of Set 10 | ust-nera
# Processing Record 3 of Set 10 | svetlogorsk
# Processing Record 4 of Set 10 | jalu
# Processing Record 5 of Set 10 | fortuna
# Processing Record 6 of Set 10 | hastings
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | krasnokamensk
# Processing Record 9 of Set 10 | tabou
# Processing Record 10 of Set 10 | verkhniy mamon
# Processing Record 11 of Set 10 | barmer
# Processing Record 12 of Set 10 | lapua
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | nalut
# Processing Record 15 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 10 | rio grande
# Processing Record 17 of Set 10 | plouzane
# Processing Record 18 of Set 10 | isangel
# Processing Record 19 of Set 10 | shitanjing
# Processing Record 20 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 10 | sur
# Processing Record 22 of Set 10 | cabo san lucas
# Processing Record 23 of Set 10 | taber
# Processing Record 24 of Set 10 | general pico
# Processing Record 25 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 10 | koupela
# Processing Record 27 of Set 10 | ozu
# Processing Record 28 of Set 10 | ust-karsk
# Processing Record 29 of Set 10 | yarada
# Processing Record 30 of Set 10 | smirnykh
# Processing Record 31 of Set 10 | glasgow
# Processing Record 32 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 33 of Set 10 | masyaf
# Processing Record 34 of Set 10 | allanmyo
# City not found. Skipping...
# Processing Record 35 of Set 10 | gizo
# Processing Record 36 of Set 10 | sabang
# Processing Record 37 of Set 10 | sarangani
# Processing Record 38 of Set 10 | hammerfest
# Processing Record 39 of Set 10 | lewiston
# Processing Record 40 of Set 10 | saucillo
# Processing Record 41 of Set 10 | lorengau
# Processing Record 42 of Set 10 | port hedland
# Processing Record 43 of Set 10 | borogontsy
# Processing Record 44 of Set 10 | zhigansk
# Processing Record 45 of Set 10 | wanning
# Processing Record 46 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 10 | vostok
# Processing Record 48 of Set 10 | houma
# Processing Record 49 of Set 10 | touros
# Processing Record 50 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 11 | dasoguz
# Processing Record 2 of Set 11 | oranjemund
# Processing Record 3 of Set 11 | nuevitas
# Processing Record 4 of Set 11 | kulhudhuffushi
# Processing Record 5 of Set 11 | hearst
# Processing Record 6 of Set 11 | mossendjo
# Processing Record 7 of Set 11 | basco
# Processing Record 8 of Set 11 | vilhena
# Processing Record 9 of Set 11 | bulungu
# Processing Record 10 of Set 11 | sorland
# Processing Record 11 of Set 11 | adre
# Processing Record 12 of Set 11 | zheshart
# Processing Record 13 of Set 11 | bambous virieux
# Processing Record 14 of Set 11 | coquimbo
# Processing Record 15 of Set 11 | witu
# Processing Record 16 of Set 11 | bambanglipuro
# Processing Record 17 of Set 11 | diofior
# Processing Record 18 of Set 11 | north bend
# Processing Record 19 of Set 11 | khovu-aksy
# Processing Record 20 of Set 11 | lukang
# Processing Record 21 of Set 11 | abu zabad
# Processing Record 22 of Set 11 | kosino
# Processing Record 23 of Set 11 | volsk
# Processing Record 24 of Set 11 | polson
# Processing Record 25 of Set 11 | avera
# Processing Record 26 of Set 11 | taoudenni
# Processing Record 27 of Set 11 | churapcha
# Processing Record 28 of Set 11 | cayenne
# Processing Record 29 of Set 11 | dubti
# Processing Record 30 of Set 11 | joutseno
# Processing Record 31 of Set 11 | tura
# Processing Record 32 of Set 11 | lahaina
# Processing Record 33 of Set 11 | puerto del rosario
# Processing Record 34 of Set 11 | hovd
# Processing Record 35 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 36 of Set 11 | merauke
# Processing Record 37 of Set 11 | dunedin
# Processing Record 38 of Set 11 | nevelsk
# Processing Record 39 of Set 11 | almeria
# Processing Record 40 of Set 11 | timbiqui
# Processing Record 41 of Set 11 | xining
# Processing Record 42 of Set 11 | ibra
# Processing Record 43 of Set 11 | hellin
# Processing Record 44 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | san quintin
# Processing Record 46 of Set 11 | la palma
# Processing Record 47 of Set 11 | ulladulla
# Processing Record 48 of Set 11 | lamu
# Processing Record 49 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 50 of Set 11 | kutum
# Processing Record 1 of Set 12 | santa catalina
# Processing Record 2 of Set 12 | boyolangu
# Processing Record 3 of Set 12 | aykino
# Processing Record 4 of Set 12 | phonhong
# Processing Record 5 of Set 12 | agdas
# Processing Record 6 of Set 12 | bastrop
# Processing Record 7 of Set 12 | rong kwang
# Processing Record 8 of Set 12 | yishui
# Processing Record 9 of Set 12 | gat
# Processing Record 10 of Set 12 | shumskiy
# Processing Record 11 of Set 12 | volnovakha
# Processing Record 12 of Set 12 | linxia
# Processing Record 13 of Set 12 | baijiantan
# Processing Record 14 of Set 12 | havoysund
# Processing Record 15 of Set 12 | seymchan
# Processing Record 16 of Set 12 | pemangkat
# Processing Record 17 of Set 12 | kita
# Processing Record 18 of Set 12 | port-gentil
# Processing Record 19 of Set 12 | les cayes
# Processing Record 20 of Set 12 | dalvik
# Processing Record 21 of Set 12 | jampur
# Processing Record 22 of Set 12 | raudeberg
# Processing Record 23 of Set 12 | kudahuvadhoo
# Processing Record 24 of Set 12 | muros
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | butembo
# Processing Record 27 of Set 12 | maneadero
# Processing Record 28 of Set 12 | falam
# Processing Record 29 of Set 12 | branistea
# Processing Record 30 of Set 12 | biltine
# Processing Record 31 of Set 12 | olafsvik
# Processing Record 32 of Set 12 | meulaboh
# Processing Record 33 of Set 12 | orlik
# Processing Record 34 of Set 12 | tateyama
# Processing Record 35 of Set 12 | ekhabi
# Processing Record 36 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 12 | damietta
# Processing Record 38 of Set 12 | stekolnyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | sola
# Processing Record 40 of Set 12 | bandundu
# Processing Record 41 of Set 12 | bam
# Processing Record 42 of Set 12 | walvis bay
# Processing Record 43 of Set 12 | xinmin
# Processing Record 44 of Set 12 | lao cai
# Processing Record 45 of Set 12 | kuusamo
# Processing Record 46 of Set 12 | kangaatsiaq
# Processing Record 47 of Set 12 | requena
# Processing Record 48 of Set 12 | karratha
# Processing Record 49 of Set 12 | morro bay
# Processing Record 50 of Set 12 | chuzhou
# Processing Record 1 of Set 13 | ostrovnoy
# Processing Record 2 of Set 13 | kapit
# Processing Record 3 of Set 13 | nuqui
# Processing Record 4 of Set 13 | kameda
# Processing Record 5 of Set 13 | gari
# Processing Record 6 of Set 13 | abha
# Processing Record 7 of Set 13 | cockburn town
# Processing Record 8 of Set 13 | jumla
# Processing Record 9 of Set 13 | los llanos de aridane
# Processing Record 10 of Set 13 | madinat sittah uktubar
# Processing Record 11 of Set 13 | shimoda
# Processing Record 12 of Set 13 | sibolga
# Processing Record 13 of Set 13 | tecoanapa
# Processing Record 14 of Set 13 | lashma
# Processing Record 15 of Set 13 | ugoofaaru
# Processing Record 16 of Set 13 | micheweni
# Processing Record 17 of Set 13 | shelburne
# Processing Record 18 of Set 13 | andilamena
# Processing Record 19 of Set 13 | tsabong
# Processing Record 20 of Set 13 | saint-francois
# Processing Record 21 of Set 13 | hakvik
# City not found. Skipping...
# Processing Record 22 of Set 13 | vanimo
# Processing Record 23 of Set 13 | kerouane
# Processing Record 24 of Set 13 | yermakovskoye
# Processing Record 25 of Set 13 | palu
# Processing Record 26 of Set 13 | muisne
# Processing Record 27 of Set 13 | sala
# Processing Record 28 of Set 13 | bu salim
# City not found. Skipping...
# Processing Record 29 of Set 13 | korla
# Processing Record 30 of Set 13 | dali
# Processing Record 31 of Set 13 | tukrah
# Processing Record 32 of Set 13 | kyotera
# Processing Record 33 of Set 13 | oistins
# Processing Record 34 of Set 13 | barabinsk
# Processing Record 35 of Set 13 | sabha
# Processing Record 36 of Set 13 | oil city
# Processing Record 37 of Set 13 | ellensburg
# Processing Record 38 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 13 | awbari
# Processing Record 40 of Set 13 | birao
# Processing Record 41 of Set 13 | abnub
# Processing Record 42 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 43 of Set 13 | puerto leguizamo
# Processing Record 44 of Set 13 | rundu
# Processing Record 45 of Set 13 | broken hill
# Processing Record 46 of Set 13 | juba
# Processing Record 47 of Set 13 | dzhebariki-khaya
# Processing Record 48 of Set 13 | palasa
# Processing Record 49 of Set 13 | dundalk
# Processing Record 50 of Set 13 | wawa
# Processing Record 1 of Set 14 | nynashamn
# Processing Record 2 of Set 14 | kichmengskiy gorodok
# Processing Record 3 of Set 14 | lata
# Processing Record 4 of Set 14 | golynki
# Processing Record 5 of Set 14 | novyy urengoy
# Processing Record 6 of Set 14 | burica
# City not found. Skipping...
# Processing Record 7 of Set 14 | chamba
# Processing Record 8 of Set 14 | bhuj
# Processing Record 9 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 14 | nadvoitsy
# Processing Record 11 of Set 14 | zeya
# Processing Record 12 of Set 14 | cedar city
# Processing Record 13 of Set 14 | constitucion
# Processing Record 14 of Set 14 | honningsvag
# Processing Record 15 of Set 14 | bougouni
# Processing Record 16 of Set 14 | vryburg
# Processing Record 17 of Set 14 | yokadouma
# Processing Record 18 of Set 14 | leh
# Processing Record 19 of Set 14 | ouango
# Processing Record 20 of Set 14 | molokovo
# Processing Record 21 of Set 14 | luwuk
# Processing Record 22 of Set 14 | mantua
# Processing Record 23 of Set 14 | muroto
# Processing Record 24 of Set 14 | balykshi
# Processing Record 25 of Set 14 | ingham
# Processing Record 26 of Set 14 | moron
# Processing Record 27 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 14 | plettenberg bay
# Processing Record 29 of Set 14 | tucuman
# Processing Record 30 of Set 14 | bom despacho
# Processing Record 31 of Set 14 | panorama
# Processing Record 32 of Set 14 | tuy hoa
# Processing Record 33 of Set 14 | fortuna foothills
# Processing Record 34 of Set 14 | codrington
# Processing Record 35 of Set 14 | isla mujeres
# Processing Record 36 of Set 14 | svetlaya
# Processing Record 37 of Set 14 | nemuro
# Processing Record 38 of Set 14 | itarantim
# Processing Record 39 of Set 14 | soloneshnoye
# Processing Record 40 of Set 14 | marsabit
# Processing Record 41 of Set 14 | itarema
# Processing Record 42 of Set 14 | keti bandar
# Processing Record 43 of Set 14 | safaga
# Processing Record 44 of Set 14 | sitka
# Processing Record 45 of Set 14 | gwanda
# Processing Record 46 of Set 14 | dartford
# Processing Record 47 of Set 14 | kieta
# Processing Record 48 of Set 14 | buala
# Processing Record 49 of Set 14 | timisesti
# Processing Record 50 of Set 14 | tutoia
# Processing Record 1 of Set 15 | madimba
# Processing Record 2 of Set 15 | tagusao
# Processing Record 3 of Set 15 | sindand
# City not found. Skipping...
# Processing Record 4 of Set 15 | ivrea
# Processing Record 5 of Set 15 | bongandanga
# Processing Record 6 of Set 15 | osorno
# Processing Record 7 of Set 15 | douala
# Processing Record 8 of Set 15 | berberati
# Processing Record 9 of Set 15 | sedona
# Processing Record 10 of Set 15 | sangar
# Processing Record 11 of Set 15 | licata
# Processing Record 12 of Set 15 | ilinskiy
# Processing Record 13 of Set 15 | krasnyy chikoy
# Processing Record 14 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 15 | brigham city
# Processing Record 16 of Set 15 | aklavik
# Processing Record 17 of Set 15 | sylva
# Processing Record 18 of Set 15 | nizhniy odes
# Processing Record 19 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 15 | acari
# Processing Record 21 of Set 15 | quesnel
# Processing Record 22 of Set 15 | koungou
# Processing Record 23 of Set 15 | key largo
# Processing Record 24 of Set 15 | owo
# Processing Record 25 of Set 15 | yichang
# Processing Record 26 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 27 of Set 15 | nicoya
# Processing Record 28 of Set 15 | jagtial
# Processing Record 29 of Set 15 | mae sai
# Processing Record 30 of Set 15 | dukat
# Processing Record 31 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 32 of Set 15 | barahona
# Processing Record 33 of Set 15 | sambava
# Processing Record 34 of Set 15 | binzhou
# Processing Record 35 of Set 15 | sao desiderio
# Processing Record 36 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 37 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 38 of Set 15 | yarmouth
# Processing Record 39 of Set 15 | bantilan
# Processing Record 40 of Set 15 | cody
# Processing Record 41 of Set 15 | caravelas
# Processing Record 42 of Set 15 | nguruka
# Processing Record 43 of Set 15 | brodowski
# Processing Record 44 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 15 | marawi
# Processing Record 46 of Set 15 | mpophomeni
# Processing Record 47 of Set 15 | ilabaya
# Processing Record 48 of Set 15 | komsomolskiy
# Processing Record 49 of Set 15 | anadyr
# Processing Record 50 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 16 | marco
# Processing Record 2 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 16 | paita
# Processing Record 5 of Set 16 | qeshm
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 687

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Qostanay  53.1667   63.5833     17.89        79          40
# 1           Saldanha -33.0117   17.9442     68.05        68           0
# 2           Xuanzhou  30.9525  118.7553     50.32        72         100
# 3             Atuona  -9.8000 -139.0333     79.12        79           6
# 4             Avarua -21.2078 -159.7750     80.65        83          75
# 5        Provideniya  64.3833 -173.3000    -17.10        98          92
# 6  Sao Joao Da Barra -21.6403  -41.0511     74.91        90          95
# 7             Rawson -43.3002  -65.1023     71.87        51          17
# 8       Port Lincoln -34.7333  135.8667     71.96        63           3
# 9        East London -33.0153   27.9116     68.94       100         100
#
#    Wind Speed Country                 Date Current Description
# 0       15.66      KZ  2023-02-10 05:42:01    scattered clouds
# 1        5.17      ZA  2023-02-10 05:42:01           clear sky
# 2        6.85      CN  2023-02-10 05:42:01     overcast clouds
# 3       19.91      PF  2023-02-10 05:38:00           clear sky
# 4        2.30      CK  2023-02-10 05:42:02       broken clouds
# 5        7.70      RU  2023-02-10 05:42:03     overcast clouds
# 6       12.21      BR  2023-02-10 05:42:04     overcast clouds
# 7       11.63      AR  2023-02-10 05:42:05          few clouds
# 8       19.91      AU  2023-02-10 05:42:06           clear sky
# 9        6.91      ZA  2023-02-10 05:42:06          light rain

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness" ,"Wind Speed", "Current Description"]]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Qostanay      KZ  53.1667   63.5833     17.89        79
# 1           Saldanha      ZA -33.0117   17.9442     68.05        68
# 2           Xuanzhou      CN  30.9525  118.7553     50.32        72
# 3             Atuona      PF  -9.8000 -139.0333     79.12        79
# 4             Avarua      CK -21.2078 -159.7750     80.65        83
# 5        Provideniya      RU  64.3833 -173.3000    -17.10        98
# 6  Sao Joao Da Barra      BR -21.6403  -41.0511     74.91        90
# 7             Rawson      AR -43.3002  -65.1023     71.87        51
# 8       Port Lincoln      AU -34.7333  135.8667     71.96        63
# 9        East London      ZA -33.0153   27.9116     68.94       100
#
#    Cloudiness  Wind Speed Current Description
# 0          40       15.66    scattered clouds
# 1           0        5.17           clear sky
# 2         100        6.85     overcast clouds
# 3           6       19.91           clear sky
# 4          75        2.30       broken clouds
# 5          92        7.70     overcast clouds
# 6          95       12.21     overcast clouds
# 7          17       11.63          few clouds
# 8           3       19.91           clear sky
# 9         100        6.91          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
